# %%
import feedparser #parses different versions of rss and formats
import pandas as pd

url = 'https://www.ft.com/news-feed'
#url = 'https://news.google.com/rss?hl=en-US&gl=US&ceid=US%3Aen&x=1571747254.2933'
#url = 'http://feeds.bbci.co.uk/news/technology/rss.xml'
#url = 'https://www.reddit.com/r/QuantumComputing/' #Este no funciona
fin_times = feedparser.parse(url)

# %%
len(fin_times.entries)
fin_times.keys()
# Out:
# dict_keys(['feed', 'entries', 'bozo', 'headers', 'etag', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %%
entries_titles = [fin_times.entries[i].title for i in range(len(fin_times.entries))]
entries_titles
# Out:
# ['Xi and Lam in first official talks since protests began',
#  'US stock futures gain on trade optism',
#  "Two-thirds of US voters say Trump hasn't made them better off",
#  'Occidental to cut capital spending to pay down debt',
#  'Uber shares dip as losses grow on new ventures',
#  'Hong Kong business activity dives at quickest pace in 21 years',
#  'Ex-Google chief warns of need for AI co-operation with China',
#  'Government’s starter home scheme delivers no houses',
#  'UK retail sales rise as shoppers ignore uncertainty',
#  'Spain election candidates vow tough line on Catalonia',
#  'Why economists have no chance with Leavers',
#  'We ‘experts’ should take this lack of trust seriously',
#  'We don’t pretend that tobacco is harmless',
#  'US rejected the skilled immigration model',
#  'French are still trying to invent victories',
#  'FT Crossword: Number 16,316',
#  'Indian government accused of spying through WhatsApp',
# ...

# %%
df = pd.DataFrame(fin_times.entries)
df.head(10)
# Out:
#    guidislink                                    id  \
# 0       False  388613f0-ff6b-11e9-b7bc-f3fa4e77dd47
# 1       False  801b246a-ff68-11e9-b7bc-f3fa4e77dd47
# 2       False  f764fdba-b6d2-4d46-be19-7e3ca403e1ec
# 3       False  9f762a7e-ff51-11e9-b7bc-f3fa4e77dd47
# 4       False  7e52baac-ff46-11e9-be59-e49b2a136b8d
# 5       False  9b0fb6aa-ff63-11e9-b7bc-f3fa4e77dd47
# 6       False  6a1de5b6-ff5f-11e9-b7bc-f3fa4e77dd47
# 7       False  bdf6444c-ff07-11e9-b7bc-f3fa4e77dd47
# 8       False  929460ee-ff03-11e9-b7bc-f3fa4e77dd47
# 9       False  9de870c4-ff5e-11e9-be59-e49b2a136b8d
#
#                                                 link  \
# 0  https://www.ft.com/content/388613f0-ff6b-11e9-...
# 1  https://www.ft.com/content/801b246a-ff68-11e9-...
# 2  https://www.ft.com/video/f764fdba-b6d2-4d46-be...
# 3  https://www.ft.com/content/9f762a7e-ff51-11e9-...
# 4  https://www.ft.com/content/7e52baac-ff46-11e9-...
# 5  https://www.ft.com/content/9b0fb6aa-ff63-11e9-...
# ...

# %%
import re
#re.findall(r'quantum',df.summary[3])

for i in range(len(fin_times.entries)):
    print(re.findall(r'quantum',df.title[i]))
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
