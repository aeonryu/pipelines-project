# %% [markdown]
# Are there usage/frequency limits for the API service?
#
# We are proud to provide free API service for our global community of users and recommend that you make API requests sparingly (up to 5 API requests per minute and 500 requests per day) to achieve the best server-side performance. If you would like to target a larger API call volume, please visit premium membership.

# %%
from alpha_vantage.timeseries import TimeSeries  #instalé r-alphavantage client en anaconda y pip install alpha_vantage en terminal y reinicié ananconda
# Your key here
key = 'PUII9SGD6FZ1OTEF'
ts = TimeSeries(key)
aapl, meta = ts.get_daily(symbol='AAPL') #esto creo que me da datos diarios, pero hay que llamarlos aparte
print(aapl['2019-09-12']) #Esta llamada es de sólo un día
# Out:
# {'1. open': '224.8000', '2. high': '226.4200', '3. low': '222.8600', '4. close': '223.0900', '5. volume': '32226700'}

# %%
from alpha_vantage.timeseries import TimeSeries
from alpha_vantage.techindicators import TechIndicators
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt


# Your key here
key = 'PUII9SGD6FZ1OTEF'
# Chose your output format, or default to JSON (python dict)
ts = TimeSeries(key, output_format='pandas')
ti = TechIndicators(key)

# Get the data, returns a tuple
# aapl_data is a pandas dataframe, aapl_meta_data is a dict
aapl_data, aapl_meta_data = ts.get_daily(symbol='AAPL')
# aapl_sma is a dict, aapl_meta_sma also a dict
aapl_sma, aapl_meta_sma = ti.get_sma(symbol='AAPL')

# Visualization
figure(num=None, figsize=(15, 6), dpi=80, facecolor='w', edgecolor='k')
aapl_data['4. close'].plot()
plt.tight_layout()
plt.grid()
plt.show()

# %%
aapl_data
#dataframe
# Out:
#              1. open   2. high    3. low  4. close     5. volume
# date
# 2019-06-13  194.7000  196.7900  193.6000    194.15  2.167460e+07
# 2019-06-14  191.5384  193.5860  190.3000    192.74  1.876150e+07
# 2019-06-17  192.9000  194.9553  192.1700    193.89  1.466910e+07
# 2019-06-18  196.0500  200.2900  195.2100    198.45  2.655100e+07
# 2019-06-19  199.6800  199.8800  197.3057    197.87  2.112420e+07
# 2019-06-20  200.3543  200.6100  198.0300    199.46  2.151400e+07
# 2019-06-21  198.8000  200.8500  198.1500    198.78  4.780060e+07
# 2019-06-24  198.5400  200.1600  198.1700    198.58  1.822040e+07
# 2019-06-25  198.4300  199.2600  195.2900    195.57  2.107030e+07
# 2019-06-26  197.7700  200.9900  197.3494    199.80  2.606750e+07
# 2019-06-27  200.2900  201.5700  199.5700    199.74  2.089970e+07
# 2019-06-28  198.6800  199.4950  197.0500    197.92  3.111060e+07
# 2019-07-01  203.1700  204.4900  200.6500    201.55  2.725300e+07
# 2019-07-02  201.4100  203.1320  201.3600    202.73  1.693520e+07
# 2019-07-03  203.2800  204.4400  202.6900    204.41  1.136200e+07
# 2019-07-05  203.3500  205.0800  202.8856    204.23  1.726550e+07
# 2019-07-08  200.8100  201.4000  198.4100    200.02  2.533860e+07
# 2019-07-09  199.2000  201.5100  198.8100    201.24  2.057800e+07
# 2019-07-10  201.8500  203.7300  201.5679    203.23  1.789710e+07
# 2019-07-11  203.3137  204.3900  201.7100    201.75  2.019180e+07
# 2019-07-12  202.4500  203.9983  202.2000    203.30  1.759520e+07
# 2019-07-15  204.0900  205.8700  204.0000    205.21  1.694740e+07
# 2019-07-16  204.5900  206.1100  203.5000    204.50  1.686680e+07
# 2019-07-17  204.0500  205.0900  203.2700    203.35  1.410750e+07
# 2019-07-18  204.0000  205.8800  203.7000    205.66  1.854060e+07
# 2019-07-19  205.7900  206.5000  202.3600    202.59  2.092930e+07
# 2019-07-22  203.6500  207.2300  203.6100    207.22  2.227790e+07
# 2019-07-23  208.4600  208.9100  207.2900    208.84  1.835520e+07
# 2019-07-24  207.6700  209.1500  207.1700    208.67  1.499160e+07
# 2019-07-25  208.8900  209.2400  206.7300    207.02  1.390960e+07
# ...              ...       ...       ...       ...           ...
# 2019-09-23  218.9500  219.8400  217.6500    218.72  1.916550e+07
# 2019-09-24  221.0300  222.4900  217.1900    217.68  3.119080e+07
# 2019-09-25  218.5500  221.5000  217.1400    221.03  2.190340e+07
# 2019-09-26  220.0000  220.9400  218.8300    219.89  1.883350e+07
# 2019-09-27  220.5400  220.9600  217.2800    218.82  2.535200e+07
# 2019-09-30  220.9000  224.5800  220.7900    223.97  2.597740e+07
# 2019-10-01  225.0700  228.2200  224.2000    224.59  3.480580e+07
# 2019-10-02  223.0600  223.5800  217.9300    218.96  3.461230e+07
# 2019-10-03  218.4300  220.9600  215.1300    220.82  2.860650e+07
# 2019-10-04  225.6400  227.4900  223.8900    227.01  3.461970e+07
# 2019-10-07  226.2700  229.9300  225.8400    227.06  3.057650e+07
# 2019-10-08  225.8200  228.0600  224.3300    224.40  2.795500e+07
# 2019-10-09  227.0300  227.7900  225.6400    227.03  1.869260e+07
# 2019-10-10  227.9300  230.4400  227.3000    230.09  2.825340e+07
# 2019-10-11  232.9500  237.6400  232.3100    236.21  4.169890e+07
# 2019-10-14  234.9000  238.1300  234.6700    235.87  2.410690e+07
# 2019-10-15  236.3900  237.6500  234.8800    235.32  2.184000e+07
# 2019-10-16  233.3700  235.2400  233.2000    234.37  1.847580e+07
# 2019-10-17  235.0900  236.1500  233.5200    235.28  1.689630e+07
# 2019-10-18  234.5900  237.5800  234.2900    236.41  2.435840e+07
# 2019-10-21  237.5200  240.9900  237.3200    240.51  2.181180e+07
# 2019-10-22  241.1600  242.2000  239.6200    239.96  2.057340e+07
# 2019-10-23  242.1000  243.2400  241.2200    243.18  1.895720e+07
# 2019-10-24  244.5100  244.8000  241.8100    243.58  1.731880e+07
# 2019-10-25  243.1600  246.7300  242.8800    246.58  1.833050e+07
# 2019-10-28  247.4200  249.2500  246.7200    249.05  2.411250e+07
# 2019-10-29  248.9700  249.7500  242.5700    243.29  3.566010e+07
# 2019-10-30  244.7600  245.3000  241.2100    243.26  3.095060e+07
# 2019-10-31  247.2400  249.1700  237.2600    248.76  3.476660e+09
# 2019-11-01  249.5400  255.9300  249.1600    255.82  3.691054e+07
#
# [100 rows x 5 columns]

# %%
aapl_meta_data #diccionario
#datos relevantes: tipo de información, simbolo de la acción, ultima actualización, tipo de salida, hora global
# Out:
# {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#  '2. Symbol': 'AAPL',
#  '3. Last Refreshed': '2019-11-01',
#  '4. Output Size': 'Compact',
#  '5. Time Zone': 'US/Eastern'}

# %%
aapl_sma #diccionario de diccionarios
len(aapl_sma)
#el sma es 'Simple moving average'
# A simple, or arithmetic, moving average that is calculated by adding the closing price
# of the security for a number of time periods and then dividing this total by that same 
# number of periods. Short-term averages respond quickly to changes in the price of the 
# underlying, while long-term averages are slow to react."""
# Out:
# 5014

# %%
aapl_meta_sma #diccionario de datos sobre la info
# Out:
# {'1: Symbol': 'AAPL',
#  '2: Indicator': 'Simple Moving Average (SMA)',
#  '3: Last Refreshed': '2019-11-01',
#  '4: Interval': 'daily',
#  '5: Time Period': 20,
#  '6: Series Type': 'close',
#  '7: Time Zone': 'US/Eastern'}
